# %% [markdown]
# ### Case Grammer Example

# %%
# !pip install spacy
# Out:
# Unable to create process using 'C:\Users\Gayatri kulkarni\anaconda3\python.exe "C:\Users\Gayatri kulkarni\anaconda3\Scripts\pip-script.py" install spacy'

# %%
import spacy

# Load the NLP model
nlp = spacy.load("en_core_web_sm")

class CaseGrammar:
    def __init__(self, sentence):
        self.sentence = sentence
        self.doc = nlp(sentence)
        self.cases = {
            'Agent': None,
            'Theme': None,
            'Recipient': None,
            'Instrument': None,
            'Experiencer': None,
            'Location': None,
            'Goal': None,
            'Time': None
        }
        self.predicate = None

    def parse(self):
        for token in self.doc:
            if token.dep_ == 'ROOT':
                self.predicate = token.text
            elif token.dep_ == 'nsubj':
                self.cases['Agent'] = token.text
            elif token.dep_ == 'dobj':
                self.cases['Theme'] = token.text
            elif token.dep_ == 'pobj':
                if token.head.dep_ == 'prep' and token.head.head.dep_ == 'ROOT':
                    if token.head.text in ['to', 'for']:
                        self.cases['Recipient'] = token.text
                    elif token.head.text in ['with']:
                        self.cases['Instrument'] = token.text
                    elif token.head.text in ['in', 'at']:
                        self.cases['Location'] = token.text
                    elif token.head.text in ['by']:
                        self.cases['Experiencer'] = token.text
                elif token.head.dep_ == 'prep':
                    if token.head.text in ['on', 'in']:
                        self.cases['Time'] = token.text

    def print_cases(self):
        print(f"Predicate: {self.predicate}")
        for case, value in self.cases.items():
            if value:
                print(f"{case}: {value}")

## Input sentence
sentence = "John gave a book to Mary."
#sentence = "He gave a coffee to her."
#sentence = "I hate to watch movies."
# Parse the sentence
parser = CaseGrammar(sentence)
parser.parse()
parser.print_cases()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import spacy
#       3 # Load the NLP model
#       4 nlp = spacy.load("en_core_web_sm")
#
# File ~\anaconda3\Lib\site-packages\spacy\__init__.py:6
#       3 from typing import Any, Dict, Iterable, Union
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File ~\anaconda3\Lib\site-packages\spacy\errors.py:3
#       1 import warnings
# ----> 3 from .compat import Literal
#       6 class ErrorsWithCodes(type):
#       7     def __getattribute__(self, code):
#
# File ~\anaconda3\Lib\site-packages\spacy\compat.py:4
#       1 """Helpers for Python and platform compatibility."""
#       2 import sys
# ----> 4 from thinc.util import copy_array
#       6 try:
#       7     import cPickle as pickle
#
# File ~\anaconda3\Lib\site-packages\thinc\__init__.py:5
#       2 import numpy
#       4 from .about import __version__
# ----> 5 from .config import registry
#       7 # fmt: off
#       8 __all__ = [
#       9     "registry",
#      10     "__version__",
#      11 ]
#
# File ~\anaconda3\Lib\site-packages\thinc\config.py:5
#       2 import confection
#       3 from confection import VARIABLE_RE, Config, ConfigValidationError, Promise
# ----> 5 from .types import Decorator
#       8 class registry(confection.registry):
#       9     # fmt: off
#      10     optimizers: Decorator = catalogue.create("thinc", "optimizers", entry_points=True)
#
# File ~\anaconda3\Lib\site-packages\thinc\types.py:25
#       4 from typing import (
#       5     Any,
#       6     Callable,
#    (...)
#      20     overload,
#      21 )
#      23 import numpy
# ---> 25 from .compat import cupy, has_cupy
#      27 if has_cupy:
#      28     get_array_module = cupy.get_array_module
#
# File ~\anaconda3\Lib\site-packages\thinc\compat.py:99
#      95 has_mxnet = False
#      98 try:
# ---> 99     import h5py
#     100 except ImportError:  # pragma: no cover
#     101     h5py = None
#
# File ~\anaconda3\Lib\site-packages\h5py\__init__.py:45
#      36     _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
#      37            "this may cause problems").format(
#      38             '{0}.{1}.{2}'.format(*version.hdf5_version_tuple),
#      39             '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
#      40     ))
#      43 _errors.silence_errors()
# ---> 45 from ._conv import register_converters as _register_converters, \
#      46                    unregister_converters as _unregister_converters
#      47 _register_converters()
#      48 atexit.register(_unregister_converters)
#
# File h5py\\_conv.pyx:1, in init h5py._conv()
#
# File h5py\\h5r.pyx:1, in init h5py.h5r()
#
# File h5py\\h5p.pyx:1, in init h5py.h5p()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.8.2-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.10-cp312-cp312-win_amd64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.8-cp312-cp312-win_amd64.whl.metadata (8.6 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.9-cp312-cp312-win_amd64.whl.metadata (2.2 kB)
# Collecting thinc<8.4.0,>=8.3.0 (from spacy)
#   Downloading thinc-8.3.2-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.4.8-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from spacy) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: jinja2 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from spacy) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from spacy) (23.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.4.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from spacy) (1.26.4)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading language_data-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.6.2)
# Collecting blis<1.1.0,>=1.0.0 (from thinc<8.4.0,>=8.3.0->spacy)
#   Downloading blis-1.0.1-cp312-cp312-win_amd64.whl.metadata (7.8 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.0->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Collecting numpy>=1.19.0 (from spacy)
#   Downloading numpy-2.0.2-cp312-cp312-win_amd64.whl.metadata (59 kB)
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ---------------------------------------- 59.7/59.7 kB ? eta 0:00:00
# Requirement already satisfied: colorama in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.3.5)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.19.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.3)
# Collecting marisa-trie>=0.7.7 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.2.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\gayatri kulkarni\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Downloading spacy-3.8.2-cp312-cp312-win_amd64.whl (11.8 MB)
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.8 MB 16.5 MB/s eta 0:00:01
#    - -------------------------------------- 0.6/11.8 MB 17.5 MB/s eta 0:00:01
#    --- ------------------------------------ 1.0/11.8 MB 7.8 MB/s eta 0:00:02
#    --- ------------------------------------ 1.2/11.8 MB 8.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.4/11.8 MB 6.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.7/11.8 MB 7.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.7/11.8 MB 7.4 MB/s eta 0:00:02
#    ------- -------------------------------- 2.2/11.8 MB 7.0 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/11.8 MB 7.0 MB/s eta 0:00:02
#    --------- ------------------------------ 2.7/11.8 MB 6.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.1/11.8 MB 7.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.1/11.8 MB 7.2 MB/s eta 0:00:02
#    ------------ --------------------------- 3.6/11.8 MB 6.9 MB/s eta 0:00:02
#    ------------- -------------------------- 3.9/11.8 MB 7.0 MB/s eta 0:00:02
#    ------------- -------------------------- 4.0/11.8 MB 6.6 MB/s eta 0:00:02
#    -------------- ------------------------- 4.1/11.8 MB 6.4 MB/s eta 0:00:02
#    -------------- ------------------------- 4.3/11.8 MB 6.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.8/11.8 MB 6.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.9/11.8 MB 6.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.2/11.8 MB 6.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.3/11.8 MB 6.2 MB/s eta 0:00:02
#    ------------------ --------------------- 5.6/11.8 MB 6.1 MB/s eta 0:00:02
#    -------------------- ------------------- 6.0/11.8 MB 6.3 MB/s eta 0:00:01
#    -------------------- ------------------- 6.0/11.8 MB 6.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.6/11.8 MB 6.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.8/11.8 MB 6.5 MB/s eta 0:00:01
#    ------------------------ --------------- 7.1/11.8 MB 6.4 MB/s eta 0:00:01
#    ------------------------- -------------- 7.4/11.8 MB 6.4 MB/s eta 0:00:01
#    -------------------------- ------------- 7.7/11.8 MB 6.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.3/11.8 MB 6.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.4/11.8 MB 6.5 MB/s eta 0:00:01
#    ------------------------------ --------- 8.9/11.8 MB 6.7 MB/s eta 0:00:01
#    ------------------------------- -------- 9.3/11.8 MB 6.8 MB/s eta 0:00:01
#    --------------------------------- ------ 9.8/11.8 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.3/11.8 MB 7.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.5/11.8 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------- -- 11.1/11.8 MB 7.0 MB/s eta 0:00:01
#    -------------------------------------- - 11.3/11.8 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  11.8/11.8 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.8/11.8 MB 6.9 MB/s eta 0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp312-cp312-win_amd64.whl (39 kB)
# Downloading langcodes-3.4.1-py3-none-any.whl (182 kB)
#    ---------------------------------------- 0.0/182.4 kB ? eta -:--:--
#    --------------------------------------- 182.4/182.4 kB 10.8 MB/s eta 0:00:00
# Downloading murmurhash-1.0.10-cp312-cp312-win_amd64.whl (25 kB)
# Downloading preshed-3.0.9-cp312-cp312-win_amd64.whl (122 kB)
#    ---------------------------------------- 0.0/122.4 kB ? eta -:--:--
#    ---------------------------------------- 122.4/122.4 kB 7.5 MB/s eta 0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp312-cp312-win_amd64.whl (478 kB)
#    ---------------------------------------- 0.0/478.8 kB ? eta -:--:--
#    --------------------------------------  471.0/478.8 kB 14.9 MB/s eta 0:00:01
#    --------------------------------------- 478.8/478.8 kB 10.2 MB/s eta 0:00:00
# Downloading thinc-8.3.2-cp312-cp312-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.5 MB 2.4 MB/s eta 0:00:01
#    ------------------ --------------------- 0.7/1.5 MB 8.3 MB/s eta 0:00:01
#    -------------------------------- ------- 1.2/1.5 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.5 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 8.4 MB/s eta 0:00:00
# Downloading numpy-2.0.2-cp312-cp312-win_amd64.whl (15.6 MB)
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#     --------------------------------------- 0.4/15.6 MB 11.6 MB/s eta 0:00:02
#    - -------------------------------------- 0.6/15.6 MB 7.7 MB/s eta 0:00:02
#    -- ------------------------------------- 1.2/15.6 MB 9.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.6/15.6 MB 8.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.2/15.6 MB 9.3 MB/s eta 0:00:02
#    ------ --------------------------------- 2.4/15.6 MB 8.4 MB/s eta 0:00:02
#    ------- -------------------------------- 3.0/15.6 MB 9.6 MB/s eta 0:00:02
#    -------- ------------------------------- 3.4/15.6 MB 9.1 MB/s eta 0:00:02
#    --------- ------------------------------ 3.6/15.6 MB 8.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.9/15.6 MB 8.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.5/15.6 MB 8.9 MB/s eta 0:00:02
#    ------------ --------------------------- 4.9/15.6 MB 9.0 MB/s eta 0:00:02
#    ------------- -------------------------- 5.2/15.6 MB 8.7 MB/s eta 0:00:02
#    ------------- -------------------------- 5.4/15.6 MB 8.8 MB/s eta 0:00:02
#    -------------- ------------------------- 5.6/15.6 MB 8.4 MB/s eta 0:00:02
#    --------------- ------------------------ 5.9/15.6 MB 8.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.3/15.6 MB 8.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.6/15.6 MB 8.4 MB/s eta 0:00:02
#    ------------------ --------------------- 7.1/15.6 MB 8.5 MB/s eta 0:00:02
#    ------------------ --------------------- 7.3/15.6 MB 8.6 MB/s eta 0:00:01
#    -------------------- ------------------- 7.8/15.6 MB 8.6 MB/s eta 0:00:01
#    --------------------- ------------------ 8.3/15.6 MB 8.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.6/15.6 MB 8.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.2/15.6 MB 8.7 MB/s eta 0:00:01
#    ------------------------ --------------- 9.4/15.6 MB 8.6 MB/s eta 0:00:01
#    ------------------------- -------------- 10.0/15.6 MB 8.7 MB/s eta 0:00:01
#    -------------------------- ------------- 10.3/15.6 MB 8.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 10.9/15.6 MB 9.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.3/15.6 MB 9.0 MB/s eta 0:00:01
#    ------------------------------ --------- 11.7/15.6 MB 9.0 MB/s eta 0:00:01
#    ------------------------------ --------- 12.0/15.6 MB 8.8 MB/s eta 0:00:01
#    -------------------------------- ------- 12.7/15.6 MB 8.8 MB/s eta 0:00:01
#    --------------------------------- ------ 13.1/15.6 MB 8.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.7/15.6 MB 8.8 MB/s eta 0:00:01
#    ------------------------------------ --- 14.1/15.6 MB 9.1 MB/s eta 0:00:01
#    ------------------------------------- -- 14.7/15.6 MB 9.1 MB/s eta 0:00:01
#    -------------------------------------- - 15.1/15.6 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  15.6/15.6 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 15.6/15.6 MB 8.8 MB/s eta 0:00:00
# Downloading typer-0.12.5-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.3 kB ? eta -:--:--
#    ---------------------------------------- 47.3/47.3 kB ? eta 0:00:00
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/50.3 kB ? eta -:--:--
#    ---------------------------------------- 50.3/50.3 kB 2.7 MB/s eta 0:00:00
# Downloading blis-1.0.1-cp312-cp312-win_amd64.whl (6.4 MB)
#    ---------------------------------------- 0.0/6.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/6.4 MB 10.2 MB/s eta 0:00:01
#    ------ --------------------------------- 1.0/6.4 MB 10.7 MB/s eta 0:00:01
#    -------- ------------------------------- 1.4/6.4 MB 9.7 MB/s eta 0:00:01
#    ------------ --------------------------- 2.0/6.4 MB 10.5 MB/s eta 0:00:01
#    -------------- ------------------------- 2.4/6.4 MB 9.5 MB/s eta 0:00:01
#    ------------------- -------------------- 3.1/6.4 MB 10.2 MB/s eta 0:00:01
#    --------------------- ------------------ 3.4/6.4 MB 9.8 MB/s eta 0:00:01
#    ------------------------- -------------- 4.1/6.4 MB 10.4 MB/s eta 0:00:01
#    --------------------------- ------------ 4.4/6.4 MB 10.0 MB/s eta 0:00:01
#    ------------------------------- -------- 5.0/6.4 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.4/6.4 MB 9.9 MB/s eta 0:00:01
#    ------------------------------------- -- 6.0/6.4 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  6.4/6.4 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.4/6.4 MB 9.5 MB/s eta 0:00:00
# Downloading cloudpathlib-0.19.0-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.4 kB ? eta -:--:--
#    ---------------------------------------- 49.4/49.4 kB ? eta 0:00:00
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading language_data-1.2.0-py3-none-any.whl (5.4 MB)
#    ---------------------------------------- 0.0/5.4 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.4 MB 10.0 MB/s eta 0:00:01
#    ------ --------------------------------- 0.8/5.4 MB 13.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.4/5.4 MB 10.9 MB/s eta 0:00:01
#    -------------- ------------------------- 1.9/5.4 MB 11.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.4/5.4 MB 10.7 MB/s eta 0:00:01
#    --------------------- ------------------ 2.9/5.4 MB 11.0 MB/s eta 0:00:01
#    ------------------------- -------------- 3.4/5.4 MB 10.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.9/5.4 MB 10.3 MB/s eta 0:00:01
#    -------------------------------- ------- 4.3/5.4 MB 10.3 MB/s eta 0:00:01
#    ------------------------------------ --- 4.9/5.4 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------  5.3/5.4 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------  5.4/5.4 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 5.4/5.4 MB 9.6 MB/s eta 0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading marisa_trie-1.2.0-cp312-cp312-win_amd64.whl (151 kB)
#    ---------------------------------------- 0.0/151.1 kB ? eta -:--:--
#    ---------------------------------------- 151.1/151.1 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, shellingham, numpy, murmurhash, marisa-trie, cloudpathlib, catalogue, srsly, preshed, language-data, blis, typer, langcodes, confection, weasel, thinc, spacy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed blis-1.0.1 catalogue-2.0.10 cloudpathlib-0.19.0 confection-0.1.5 cymem-2.0.8 langcodes-3.4.1 language-data-1.2.0 marisa-trie-1.2.0 murmurhash-1.0.10 numpy-2.0.2 preshed-3.0.9 shellingham-1.5.4 spacy-3.8.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.3.2 typer-0.12.5 wasabi-1.1.3 weasel-0.4.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Gayatri kulkarni\anaconda3\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.0.2 which is incompatible.
# numba 0.59.1 requires numpy<1.27,>=1.22, but you have numpy 2.0.2 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you have numpy 2.0.2 which is incompatible.
# streamlit 1.32.0 requires numpy<2,>=1.19.3, but you have numpy 2.0.2 which is incompatible.
