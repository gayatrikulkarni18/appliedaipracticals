# %%
Program : Genetic Algorithm to Solve a Simple String Matching Problem
This example demonstrates a genetic algorithm that evolves a population of strings to match a target string.

# %%
import random
import string

# Genetic Algorithm parameters
target_string = "HELLO"
population_size = 10
mutation_rate = 0.01
generations = 100

# Fitness function: number of characters matching the target
def fitness(individual):
    return sum(1 for a, b in zip(individual, target_string) if a == b)

# Create initial population (random strings)
def create_population(size):
    return [''.join(random.choices(string.ascii_uppercase, k=len(target_string))) for _ in range(size)]

# Select parents (tournament selection)
def select_parents(population):
    tournament = random.sample(population, 3)
    return max(tournament, key=fitness)

# Crossover (single-point crossover)
def crossover(parent1, parent2):
    crossover_point = random.randint(1, len(parent1) - 1)
    return parent1[:crossover_point] + parent2[crossover_point:]

# Mutation (random character mutation)
def mutate(individual):
    individual = list(individual)
    for i in range(len(individual)):
        if random.random() < mutation_rate:
            individual[i] = random.choice(string.ascii_uppercase)
    return ''.join(individual)

# Main genetic algorithm loop
population = create_population(population_size)
for generation in range(generations):
    print(f"Generation {generation}: Best individual: {max(population, key=fitness)}")
    
    # Create new generation
    new_population = []
    for _ in range(population_size):
        parent1 = select_parents(population)
        parent2 = select_parents(population)
        child = crossover(parent1, parent2)
        child = mutate(child)
        new_population.append(child)
    
    population = new_population

# Best individual in the final population
best_individual = max(population, key=fitness)
print(f"Best individual: {best_individual}, Fitness: {fitness(best_individual)}")
print('Gayatri Kulkarni-53004230002')
# Out:
# Generation 0: Best individual: HFHSW
# Generation 1: Best individual: HLKRO
# Generation 2: Best individual: HLKRO
# Generation 3: Best individual: HIKRO
# Generation 4: Best individual: HIKRO
# Generation 5: Best individual: HLKRO
# Generation 6: Best individual: HLKRO
# Generation 7: Best individual: HLKRO
# Generation 8: Best individual: HLKRO
# Generation 9: Best individual: HLKRO
# Generation 10: Best individual: HLKRO
# Generation 11: Best individual: HLKRO
# Generation 12: Best individual: HLKRO
# Generation 13: Best individual: HLKRO
# Generation 14: Best individual: HLKRO
# Generation 15: Best individual: HLKRO
# Generation 16: Best individual: HLKRO
# Generation 17: Best individual: HDKRO
# Generation 18: Best individual: HLKRO
# Generation 19: Best individual: HLKRO
# Generation 20: Best individual: HLKRO
# Generation 21: Best individual: HLKRO
# Generation 22: Best individual: HLKRO
# Generation 23: Best individual: HLKRO
# Generation 24: Best individual: HLKRO
# Generation 25: Best individual: HLKRO
# Generation 26: Best individual: HLKRO
# Generation 27: Best individual: HLKRO
# Generation 28: Best individual: HLKRO
# Generation 29: Best individual: HLKRO
# Generation 30: Best individual: HLKRO
# Generation 31: Best individual: HLKFO
# Generation 32: Best individual: HLKDO
# Generation 33: Best individual: HLKRO
# Generation 34: Best individual: HLVRO
# Generation 35: Best individual: HLARO
# Generation 36: Best individual: HLKDO
# Generation 37: Best individual: HLKVO
# Generation 38: Best individual: HLKVO
# Generation 39: Best individual: HLKDO
# Generation 40: Best individual: HLKVO
# Generation 41: Best individual: HLRVO
# Generation 42: Best individual: HLKRO
# Generation 43: Best individual: HLKVO
# Generation 44: Best individual: HLKVO
# Generation 45: Best individual: HLKVO
# Generation 46: Best individual: HLKVO
# Generation 47: Best individual: HLKVO
# Generation 48: Best individual: HLKVO
# Generation 49: Best individual: HLKRO
# Generation 50: Best individual: HLKVO
# Generation 51: Best individual: HLBRO
# Generation 52: Best individual: HLKVO
# Generation 53: Best individual: HLKRO
# Generation 54: Best individual: HLKRO
# Generation 55: Best individual: HLKVO
# Generation 56: Best individual: HLKRO
# Generation 57: Best individual: HLKVO
# Generation 58: Best individual: HLKRO
# Generation 59: Best individual: HLKVO
# Generation 60: Best individual: HLKVO
# Generation 61: Best individual: HLKVO
# Generation 62: Best individual: HLKRO
# Generation 63: Best individual: HLKRO
# Generation 64: Best individual: HLOVO
# Generation 65: Best individual: HLKRO
# Generation 66: Best individual: HLKVO
# Generation 67: Best individual: HLKVO
# Generation 68: Best individual: HLKVO
# Generation 69: Best individual: HLKVO
# Generation 70: Best individual: HLKVO
# Generation 71: Best individual: HLKVO
# Generation 72: Best individual: HLLVO
# Generation 73: Best individual: HLLVO
# Generation 74: Best individual: HLLVO
# Generation 75: Best individual: HLLVO
# Generation 76: Best individual: HLLVO
# Generation 77: Best individual: HLLVO
# Generation 78: Best individual: HLLVO
# Generation 79: Best individual: HLLVO
# Generation 80: Best individual: HLLVO
# Generation 81: Best individual: HLLVO
# Generation 82: Best individual: HLLVO
# Generation 83: Best individual: HLLEO
# Generation 84: Best individual: HLLCO
# Generation 85: Best individual: HLLVO
# Generation 86: Best individual: HLLVO
# Generation 87: Best individual: HLLVO
# Generation 88: Best individual: HLLVO
# Generation 89: Best individual: HLLVO
# Generation 90: Best individual: HLLVO
# Generation 91: Best individual: HLLVO
# Generation 92: Best individual: HLLVO
# Generation 93: Best individual: HLLVO
# Generation 94: Best individual: HLLVO
# Generation 95: Best individual: HJLVO
# Generation 96: Best individual: HJLVO
# Generation 97: Best individual: HELVO
# Generation 98: Best individual: HELVO
# Generation 99: Best individual: HELVO
# Best individual: HELVO, Fitness: 4
# Gayatri Kulkarni-53004230002

# %%
import random
import string

# Genetic Algorithm parameters
target_string = "HELLO"
population_size = 50  # Increased population size
mutation_rate = 0.01
generations = 200  # Increased generations for more evolution

# Fitness function: number of characters matching the target
def fitness(individual):
    return sum(1 for a, b in zip(individual, target_string) if a == b)

# Create initial population (random strings)
def create_population(size):
    return [''.join(random.choices(string.ascii_uppercase, k=len(target_string))) for _ in range(size)]

# Select parents (tournament selection)
def select_parents(population):
    tournament = random.sample(population, 5)  # Select 5 individuals instead of 3 for better diversity
    return max(tournament, key=fitness)

# Crossover (single-point crossover)
def crossover(parent1, parent2):
    crossover_point = random.randint(1, len(parent1) - 1)
    return parent1[:crossover_point] + parent2[crossover_point:]

# Mutation (random character mutation)
def mutate(individual):
    individual = list(individual)
    for i in range(len(individual)):
        if random.random() < mutation_rate:
            individual[i] = random.choice(string.ascii_uppercase)
    return ''.join(individual)

# Main genetic algorithm loop
population = create_population(population_size)
for generation in range(generations):
    best_individual = max(population, key=fitness)
    print(f"Generation {generation}: Best individual: {best_individual}, Fitness: {fitness(best_individual)}")
    
    if fitness(best_individual) == len(target_string):  # Stop early if the optimal solution is found
        break
    
    # Create new generation
    new_population = []
    for _ in range(population_size):
        parent1 = select_parents(population)
        parent2 = select_parents(population)
        child = crossover(parent1, parent2)
        child = mutate(child)
        new_population.append(child)
    
    population = new_population

# Best individual in the final population
best_individual = max(population, key=fitness)
print(f"Best individual: {best_individual}, Fitness: {fitness(best_individual)}")
print('Gayatri Kulkarni-53004230002')
# Out:
# Generation 0: Best individual: QKLIR, Fitness: 1
# Generation 1: Best individual: HINLI, Fitness: 2
# Generation 2: Best individual: HNLLC, Fitness: 3
# Generation 3: Best individual: HNLLR, Fitness: 3
# Generation 4: Best individual: HNLLC, Fitness: 3
# Generation 5: Best individual: HELLC, Fitness: 4
# Generation 6: Best individual: HELLR, Fitness: 4
# Generation 7: Best individual: HELLC, Fitness: 4
# Generation 8: Best individual: HELLC, Fitness: 4
# Generation 9: Best individual: HELLC, Fitness: 4
# Generation 10: Best individual: HELLC, Fitness: 4
# Generation 11: Best individual: HELLC, Fitness: 4
# Generation 12: Best individual: HELLC, Fitness: 4
# Generation 13: Best individual: HELLC, Fitness: 4
# Generation 14: Best individual: HELLC, Fitness: 4
# Generation 15: Best individual: HELLR, Fitness: 4
# Generation 16: Best individual: HELLC, Fitness: 4
# Generation 17: Best individual: HELLC, Fitness: 4
# Generation 18: Best individual: HELLC, Fitness: 4
# Generation 19: Best individual: HELLC, Fitness: 4
# Generation 20: Best individual: HELLR, Fitness: 4
# Generation 21: Best individual: HELLC, Fitness: 4
# Generation 22: Best individual: HELLR, Fitness: 4
# Generation 23: Best individual: HELLR, Fitness: 4
# Generation 24: Best individual: HELLR, Fitness: 4
# Generation 25: Best individual: HELLC, Fitness: 4
# Generation 26: Best individual: HELLR, Fitness: 4
# Generation 27: Best individual: HELLI, Fitness: 4
# Generation 28: Best individual: HELLI, Fitness: 4
# Generation 29: Best individual: HELLC, Fitness: 4
# Generation 30: Best individual: HELLC, Fitness: 4
# Generation 31: Best individual: HELLC, Fitness: 4
# Generation 32: Best individual: HELLR, Fitness: 4
# Generation 33: Best individual: HELLC, Fitness: 4
# Generation 34: Best individual: HELLC, Fitness: 4
# Generation 35: Best individual: HELLU, Fitness: 4
# Generation 36: Best individual: HELLR, Fitness: 4
# Generation 37: Best individual: HELLR, Fitness: 4
# Generation 38: Best individual: HELLU, Fitness: 4
# Generation 39: Best individual: HELLC, Fitness: 4
# Generation 40: Best individual: HELLC, Fitness: 4
# Generation 41: Best individual: HELLR, Fitness: 4
# Generation 42: Best individual: HELLU, Fitness: 4
# Generation 43: Best individual: HELLI, Fitness: 4
# Generation 44: Best individual: HELLI, Fitness: 4
# Generation 45: Best individual: HELLU, Fitness: 4
# Generation 46: Best individual: HELLP, Fitness: 4
# Generation 47: Best individual: HELLP, Fitness: 4
# Generation 48: Best individual: HELLC, Fitness: 4
# Generation 49: Best individual: HELLC, Fitness: 4
# Generation 50: Best individual: HELLP, Fitness: 4
# Generation 51: Best individual: HELLP, Fitness: 4
# Generation 52: Best individual: HELLP, Fitness: 4
# Generation 53: Best individual: HELLY, Fitness: 4
# Generation 54: Best individual: HELLY, Fitness: 4
# Generation 55: Best individual: HELLP, Fitness: 4
# Generation 56: Best individual: HELLU, Fitness: 4
# Generation 57: Best individual: HELLU, Fitness: 4
# Generation 58: Best individual: HELLP, Fitness: 4
# Generation 59: Best individual: HELLP, Fitness: 4
# Generation 60: Best individual: HELLY, Fitness: 4
# Generation 61: Best individual: HELLY, Fitness: 4
# Generation 62: Best individual: HELLY, Fitness: 4
# Generation 63: Best individual: HELLP, Fitness: 4
# Generation 64: Best individual: HELLY, Fitness: 4
# Generation 65: Best individual: HELLP, Fitness: 4
# Generation 66: Best individual: HELLY, Fitness: 4
# Generation 67: Best individual: HELLP, Fitness: 4
# Generation 68: Best individual: HELLB, Fitness: 4
# Generation 69: Best individual: HELLP, Fitness: 4
# Generation 70: Best individual: HELLP, Fitness: 4
# Generation 71: Best individual: HELLP, Fitness: 4
# Generation 72: Best individual: HELLY, Fitness: 4
# Generation 73: Best individual: HELLP, Fitness: 4
# Generation 74: Best individual: HELLH, Fitness: 4
# Generation 75: Best individual: HELLN, Fitness: 4
# Generation 76: Best individual: HELLP, Fitness: 4
# Generation 77: Best individual: HELLP, Fitness: 4
# Generation 78: Best individual: HELLP, Fitness: 4
# Generation 79: Best individual: HELLP, Fitness: 4
# Generation 80: Best individual: HELLP, Fitness: 4
# Generation 81: Best individual: HELLP, Fitness: 4
# Generation 82: Best individual: HELLP, Fitness: 4
# Generation 83: Best individual: HELLP, Fitness: 4
# Generation 84: Best individual: HELLP, Fitness: 4
# Generation 85: Best individual: HELLP, Fitness: 4
# Generation 86: Best individual: HELLP, Fitness: 4
# Generation 87: Best individual: HELLP, Fitness: 4
# Generation 88: Best individual: HELLY, Fitness: 4
# Generation 89: Best individual: HELLV, Fitness: 4
# Generation 90: Best individual: HELLY, Fitness: 4
# Generation 91: Best individual: HELLP, Fitness: 4
# Generation 92: Best individual: HELLP, Fitness: 4
# Generation 93: Best individual: HELLP, Fitness: 4
# Generation 94: Best individual: HELLP, Fitness: 4
# Generation 95: Best individual: HELLP, Fitness: 4
# Generation 96: Best individual: HELLY, Fitness: 4
# Generation 97: Best individual: HELLY, Fitness: 4
# Generation 98: Best individual: HELLY, Fitness: 4
# Generation 99: Best individual: HELLO, Fitness: 5
# Best individual: HELLO, Fitness: 5
# Gayatri Kulkarni-53004230002

# %% [markdown]
# What Happened Here?
# Early Convergence: In this case, the algorithm reached the optimal solution "HELLO" in just 3 generations. The best individual in Generation 2 matches the target string exactly, achieving a fitness score of 5 (perfect match).
#
# Parameters: The increased population size (50 instead of 10) and the ability to run for 200 generations gave the algorithm more opportunities to explore different combinations. Additionally, a larger tournament size for selecting parents (5 individuals) helps maintain better diversity, leading to quicker convergence.

# %% [markdown]
# When you increase the population size and allow more generations, the genetic algorithm has more time and diversity to evolve toward the optimal solution. This demonstrates the importance of balancing the parameters of the genetic algorithm to improve its performance.
# The success of the algorithm depends on finding the right balance between exploration (mutation, diversity) and exploitation (selection of the best individuals).
